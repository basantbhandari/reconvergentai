# %% [markdown]
# Build perceptron from scratch

# %%
import numpy as np

# %%
import numpy as np

class Perceptron:
    def __init__(self, learning_rate=0.1, epochs=100):
        self.lr = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None
        self.errors_per_epoch = []

    def fit(self, x, y):
        n_samples, n_features = x.shape
        self.weights = np.zeros(n_features)
        self.bias = 0.0
        for epoch in range(self.epochs):
            errors = 0
            for xi, yi in zip(x, y):
                prediction = self.predict_single(xi)
                delta = self.lr * (yi - prediction)
                self.weights += delta * xi
                self.bias += delta
                errors += int(delta != 0)
            self.errors_per_epoch.append(errors)
            if errors == 0:
                break
        return self

    def predict_single(self, x):
        return int(np.dot(x, self.weights) + self.bias >= 0)

    def predict(self, x):
        return np.array([self.predict_single(xi) for xi in x])

    def score(self, x, y):
        return np.mean(self.predict(x) == y)

# %%
# AND gate
x_and = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_and = np.array([0, 0, 0, 1])
print("\n── AND gate ──")
p2 = Perceptron(learning_rate=0.1, epochs=20)
p2.fit(x_and, y_and)
print(f"Accuracy: {p2.score(x_and, y_and) * 100:.0f}%")
print(f"Learned weights: {p.weights},  bias: {p.bias:.2f}")

# OR gate
print("\n── OR gate ──")
y_or = np.array([0, 1, 1, 1])
p2 = Perceptron(learning_rate=0.1, epochs=20)
p2.fit(x_or := x_and.copy(), y_or)
print(f"Accuracy: {p2.score(x_or, y_or) * 100:.0f}%")
print(f"Learned weights: {p2.weights},  bias: {p2.bias:.2f}")

# XOR gate (should NOT converge — not linearly separable)
print("\n── XOR gate (expected to fail) ──")
y_xor = np.array([0, 1, 1, 0])
p3 = Perceptron(learning_rate=0.1, epochs=20)
p3.fit(x_and.copy(), y_xor)
print(f"Accuracy: {p3.score(x_and, y_xor) * 100:.0f}%  ← single perceptron can't solve XOR")
print(f"Learned weights: {p3.weights},  bias: {p3.bias:.2f}")
# Out:
# ── AND gate ──
# Accuracy: 100%
# Learned weights: [0.2 0.1],  bias: -0.20
#
# ── OR gate ──
# Accuracy: 100%
# Learned weights: [0.1 0.1],  bias: -0.10
#
# ── XOR gate (expected to fail) ──
# Accuracy: 50%  ← single perceptron can't solve XOR
# Learned weights: [-0.1  0. ],  bias: 0.00
